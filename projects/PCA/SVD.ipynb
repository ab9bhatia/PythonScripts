# %%
import numpy as np
import pandas as pd

# %%
food = pd.read_csv('MyFoodRatings.csv')
food2 = pd.read_csv('FoodRatings_all_same_5.csv')
food3 = pd.read_csv('FoodRatings_all_same_5_4_3.csv')

# %%
food.head()
# Out:
#   Name  Chicken  Mutton  Paneer  ChowMein  SpringRolls  Momo  Sushi  Ramen  \
# 0    A        5       5       5         0            0     0      0      0
# 1    B        4       4       4         0            0     0      0      0
# 2    C        3       3       3         0            0     0      0      0
# 3    D        2       2       2         0            0     0      0      0
# 4    E        0       0       0         2            2     2      0      0
#
#    Tempura
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
data = food.iloc[:,1:]
data2 = food2.iloc[:,1:]
data3 = food3.iloc[:,1:]
data.head()
# Out:
#    Chicken  Mutton  Paneer  ChowMein  SpringRolls  Momo  Sushi  Ramen  Tempura
# 0        5       5       5         0            0     0      0      0        0
# 1        4       4       4         0            0     0      0      0        0
# 2        3       3       3         0            0     0      0      0        0
# 3        2       2       2         0            0     0      0      0        0
# 4        0       0       0         2            2     2      0      0        0

# %%
data2
# Out:
#     Chicken  Mutton  Paneer  ChowMein  SpringRolls  Momo  Sushi  Ramen  \
# 0         5       5       5         0            0     0      0      0
# 1         5       5       5         0            0     0      0      0
# 2         5       5       5         0            0     0      0      0
# 3         5       5       5         0            0     0      0      0
# 4         0       0       0         5            5     5      0      0
# 5         0       0       0         5            5     5      0      0
# 6         0       0       0         5            5     5      0      0
# 7         0       0       0         5            5     5      0      0
# 8         0       0       0         0            0     0      5      5
# 9         0       0       0         0            0     0      5      5
# 10        0       0       0         0            0     0      5      5
# 11        0       0       0         0            0     0      5      5
#
#     Tempura
# 0         0
# 1         0
# ...

# %%
data3
# Out:
#     Chicken  Mutton  Paneer  ChowMein  SpringRolls  Momo  Sushi  Ramen  \
# 0         5       5       5         0            0     0      0      0
# 1         5       5       5         0            0     0      0      0
# 2         5       5       5         0            0     0      0      0
# 3         5       5       5         0            0     0      0      0
# 4         0       0       0         4            4     4      0      0
# 5         0       0       0         4            4     4      0      0
# 6         0       0       0         4            4     4      0      0
# 7         0       0       0         4            4     4      0      0
# 8         0       0       0         0            0     0      3      3
# 9         0       0       0         0            0     0      3      3
# 10        0       0       0         0            0     0      3      3
# 11        0       0       0         0            0     0      3      3
#
#     Tempura
# 0         0
# 1         0
# ...

# %%
u,s,vt = np.linalg.svd(data,full_matrices= True)

# %%
u.shape
# Out:
# (12, 12)

# %%
vt.shape
# Out:
# (9, 9)

# %%
s.max()
# Out:
# 12.727922061357855

# %%
np.diag(s[:3])
# Out:
# array([[ 12.72792206,   0.        ,   0.        ],
#        [  0.        ,  10.57703788,   0.        ],
#        [  0.        ,   0.        ,   8.84826058]])

# %%
np.diag(u[3:])
# Out:
# array([ -2.72165527e-01,  -3.26217015e-01,   1.64357582e-16,
#          2.77555756e-17,  -5.79857394e-01,   8.37361465e-02,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00])

# %%
pd.DataFrame(vt).head(3)
# Out:
#          0        1        2         3         4         5         6  \
# 0 -0.57735 -0.57735 -0.57735  0.000000  0.000000  0.000000  0.000000
# 1  0.00000  0.00000  0.00000 -0.637875 -0.512261 -0.575068  0.000000
# 2  0.00000  0.00000  0.00000  0.000000  0.000000  0.000000 -0.476163
#
#           7         8
# 0  0.000000  0.000000
# 1  0.000000  0.000000
# 2 -0.557638 -0.679933

# %%
u,s,vt = np.linalg.svd(data2,full_matrices= True)

# %%
pd.DataFrame(s)
# Out:
#               0
# 0  1.732051e+01
# 1  1.732051e+01
# 2  1.732051e+01
# 3  3.925231e-16
# 4  2.798028e-49
# 5  0.000000e+00
# 6  0.000000e+00
# 7  0.000000e+00
# 8  0.000000e+00

# %%
u,s,vt = np.linalg.svd(data3,full_matrices= True)

# %%
pd.DataFrame(s)
# Out:
#               0
# 0  1.732051e+01
# 1  1.385641e+01
# 2  1.039230e+01
# 3  3.925231e-16
# 4  2.798028e-49
# 5  0.000000e+00
# 6  0.000000e+00
# 7  0.000000e+00
# 8  0.000000e+00
